# %%
import pandas as pd
import matplotlib.pyplot as plot
#encoding = "ISO-8859-1"
file = pd.read_csv("top25country.csv")

# %%
print(file.groupby("country")["bpm"].mean().plot(kind= "bar",ylabel = "BPM rata-rata", xlabel = "Negara", color = "xkcd:orange", title = "BPM Rata-rata Setiap Negara"))
plot.ylim(top=140,bottom=100)
# Out:
# AxesSubplot(0.125,0.11;0.775x0.77)
# (100.0, 140.0)

# %% [markdown]
# ## Visualisasi BPM rata-rata dari setiap negara dan dunia
# BPM, secara sederhana, menunjukkan seberapa cepat sebuah lagu dimainkan. Diagram batang di atas menunjukkan beats per minute (BPM) rata-rata dari 25 lagu terpopuler 17 negara berbeda dan dunia secara keseluruhan. Dari diagram batang di atas dapat dilihat bahwa sebagian besar dari negara barat memiliki BPM rata-rata yang tinggi. Indonesia memiliki BPM rata-rata yang terendah, dan Brazil memilkik BPM rata-rata yang tertinggi.

# %%
print("Average Acousticness: " + str(file["acousticness"].mean()))
print(file.groupby("country")["acousticness"].mean().plot(kind= "bar",ylabel = "Akustik rata-rata", xlabel = "Negara",color="xkcd:sea green", legend = True, title = "Akustik Rata-rata Setiap Negara"))
plot.ylim(top=50,bottom=0)
# Out:
# Average Acousticness: 34.80888888888889
# AxesSubplot(0.125,0.11;0.775x0.77)
# (0.0, 50.0)

# %% [markdown]
# ## Visualisasi akustik rata-rata dari setiap negara dan dunia
# Akustik menunjukkan seberapa jauh sebuah lagu dipengaruhi oleh alat musik atau suara elektronik, semakin tinggi tingkat akustik suatu lagu, semakin bebas lagu tersebut dari suara elektronik. Diagram batang di atas menunjukkan tingkat akustik rata-rata dari 25 lagu terpopuler 17 negara berbeda dan dunia secara keseluruhan. Diagram di atas menunjukkan bahwa sebagian besar dari negara pada data memilki tingkat akustik yang mendekati dan di atas rata-rata, yaitu 34,8 , dengan beberapa negara jauh di bawah rata-rata yaitu Argentina, Bolivia, Chili, Kolombia, dan Spanyol. Negara dengan akustik rata-rata terendah adalah Kolombia, dan negara dengan akustik rata-rata tertinggi adalah Afrika.

# %%
print(file.groupby("year")["bpm"].mean().plot(kind= "line" ,xlabel = "Tahun",ylabel = "BPM rata-rata",title = "BPM Rata-rata per Tahun",color="xkcd:orange",legend = True))
# Out:
# AxesSubplot(0.125,0.11;0.775x0.77)

# %% [markdown]
# ## Visualisasi perkembangan BPM rata-rata dari lagu populer berdasarkan tahun publikasinya
# Diagram garis di atas menunjukkan perkembangan BPM terhadap tahun dari 1940 sampai 2020. Diagram di atas menunjukkan bahwa BPM dari tahun 1940 sampai 2020 tidak memiliiki perkembangan yang stabil dengan sering adanya perubahan ekstrem tetapi secara-rata berkembang mendekati rentang 120 sampai 140 BPM.

# %%
print(file.groupby("year")["acousticness"].mean().plot(kind= "line" ,xlabel = "Tahun",ylabel = "Average Accousticness", title ="Akustik Rata-rata per Tahun",legend = True,color="xkcd:sea green"))
# Out:
# AxesSubplot(0.125,0.11;0.775x0.77)

# %% [markdown]
# ## Visualisasi perkembangan akustik rata-rata dari lagu populer berdasarkan tahun publikasinya
# Diagram garis di atas menunjukkan perkembangan akustik terhadap tahun dari 1940 sampai 2020. Diagram di atas menunjukkan bahwa akustik dari tahun 1940 sampai 2020 menurun dengan tidak stabil. Perkembangan akustik naik dan turun secara drastik dari tahun ke tahun tetapi terus turun dengan lajunya zaman. Ini bisa terhubung dengan perkembangan teknologi yang membawa berbagai teknologi elektronik baru untuk musik dan mendorong orang untuk menggunakan teknologi baru tersebut.

# %%
file2 = file.copy()
file2["top genre"] = file2["top genre"].replace(["electropop", "desi pop", "panamanian pop", "baile pop", "colombian pop","pop reggaeton","new wave pop","pop edm","latin pop","indonesian pop","k-pop","pop urbaine","pop nacional", "sertanejo pop","belgian pop","uk pop" ]," misc pop")
file2["top genre"] = file2["top genre"].replace(["glam rock", "blues rock","modern rock","heartland rock" ],"misc rock")
file2["top genre"] = file2["top genre"].replace(["dfw rap", "melodic rap","chicago rap" ]," misc rap")
file2["top genre"] = file2["top genre"].replace(["french hip hop", "canadian hip hop","nc hip hop" ,"italian hip hop", "desi hip hop"],"misc hip hop")
file2["top genre"] = file2["top genre"].replace(["alternative r&b", "canadian contemporary r&b","indie r&b" ,"r&b en espanol"],"misc r&b")
file2["top genre"] = file2["top genre"].replace(["sertanejo", "reggaeton","funk carioca","contemporary country" ,"permanent wave","electro house","sertanejo universitario","brega funk","trap italiana","axe","deep euro house","brazilian edm","francoton","boy band","modern bollywood","basshall"],"misc genres")
file2["top genre"].value_counts().plot(kind ="pie",fontsize = 8, title ="Top Genre",label="")
# Out:
# <AxesSubplot:title={'center':'Top Genre'}>

# %%
file2 = file.copy()
file2["top genre"] = file2["top genre"].replace(["electropop", "desi pop", "panamanian pop", "baile pop", "colombian pop","pop reggaeton","new wave pop","pop edm","latin pop","indonesian pop","k-pop","pop urbaine","pop nacional", "sertanejo pop","belgian pop","uk pop" ]," misc pop")
file2["top genre"] = file2["top genre"].replace(["glam rock", "blues rock","modern rock","heartland rock" ],"misc rock")
file2["top genre"] = file2["top genre"].replace(["dfw rap", "melodic rap","chicago rap" ]," misc rap")
file2["top genre"] = file2["top genre"].replace(["french hip hop", "canadian hip hop","nc hip hop" ,"italian hip hop", "desi hip hop"],"misc hip hop")
file2["top genre"] = file2["top genre"].replace(["alternative r&b", "canadian contemporary r&b","indie r&b" ,"r&b en espanol"],"misc r&b")
file2["top genre"] = file2["top genre"].replace(["sertanejo", "reggaeton","funk carioca","contemporary country" ,"permanent wave","electro house","sertanejo universitario","brega funk","trap italiana","axe","deep euro house","brazilian edm","francoton","boy band","modern bollywood","basshall"],"misc genres")
file2["top genre"].value_counts().plot(kind ="barh",fontsize = 8, title ="Top Genre",color="xkcd:mustard yellow")
# Out:
# <AxesSubplot:title={'center':'Top Genre'}>

# %% [markdown]
# ## Visualisasi hierarki data genre terpopuler
# Kedua diagram di atas menunjukkan pembagian genre dari lagu terpopuler. Berdasarkan diagram ini, jika semua jenis genre pop digabung, maka genre yang terpopuler adalah pop. Jika genre pop dipisahkan maka genre yang terpopuler adalah latin.

# %%
file2 = file.copy()
file2.loc[file2['year'] < 2000, 'year'] = 'Before 2000'
file2["year"].value_counts().plot(kind ="pie",fontsize=6,figsize= (10,10),title="Top Song Release Year", label="")
# Out:
# <AxesSubplot:title={'center':'Top Song Release Year'}>

# %%
file2 = file.copy()
b = file2["year"]
file2.loc[file2['year'] < 2000, 'year'] = 'Before 1980'
file2["year"].value_counts().plot(kind ="barh",ylabel = "Jumlah", xlabel = "Popularitas", color ="xkcd:magenta" , title= "Top Song Release Year")
# Out:
# <AxesSubplot:title={'center':'Top Song Release Year'}, ylabel='Popularitas'>

# %% [markdown]
# ## Visualisasi hierarki data tahun rilis lagu terpopuler
# Kedua diagram di atas menunjukkan tahun persentase dari tahun rilis lagu terpopuler. Berdasarkan kedua diagram tersebut, dapat dilihat bahwa sebagian besar dari lagu terpopuler berasal dari tahun 2019. Dapat disimpulkan bahwa sebagian besar dari lagu terpopuler merupakan lagu-lagu yang baru dirilis.

# %%
print(file.plot(kind="scatter", x= "acousticness", y= "popularity", color = "xkcd:sea green",xlabel = "Akustik",ylabel = "Popularitas", legend = True, title = "Hubungan Akustik Terhadap Popularitas"))
print("Koefisien korelasi: "+ str(file["acousticness"].corr(file["popularity"])))
# Out:
# AxesSubplot(0.125,0.11;0.775x0.77)
# Koefisien korelasi: -0.08306856669929946

# %% [markdown]
# ## Visualisasi hubungan tingkat akustik terhadap popularitas sebuah lagu
# Diagram di atas menunjukkan hubungan dari tingkat akustik sebuah lagu terhadap popularitasnya. Dapat dilihat dari diagram dan dari koefisien korelasi bahwa hampir tidak ada hubungan antara kedua faktor tersebut.

# %%
print(file.plot(kind="scatter", x= "duration", y= "popularity", color = "red",xlabel = "Durasi",ylabel = "Popularitas", legend = True, title = "Hubungan Durasi Lagu Terhadap Popularitas"))
print("Koefisien korelasi: " + str(file["duration"].corr(file["popularity"])))
# Out:
# AxesSubplot(0.125,0.11;0.775x0.77)
# Koefisien korelasi: -0.019697164048887137

# %% [markdown]
# ## Visualisasi hubungan durasi lagu terhadap popularitas sebuah lagu
# Diagram di atas menunjukkan hubungan dari durasi sebuah lagu terhadap popularitasnya. Dapat dilihat dari diagram dan dari koefisien korelasi bahwa tidak ada hubungan antara kedua faktor tersebut.
